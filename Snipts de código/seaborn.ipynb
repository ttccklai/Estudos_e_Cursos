# %%
import seaborn as sns

# %%
grafico = sns.catplot(
    data = base,
    x =
    y =
    hue =
    kind =
    aspect = 
    hue_order = 
    palette = 
)

for axis in grafico.axes.flat:
    for p in axis.patches:

        y = p.get_height()
        if y == 0: continue


        metade_largura = p.get_width() / 2
        
        x = p.get_x()

        cor = p.get_fc()


        axis.annotate(
            f"{y:.0f}",
            xy = (x + metade_largura + y)
            ha = 'center',
            va = 'center',
            fontsize = 11,
            color = cor
            xy_text = (0, 10)
            textcoords = 'offset points'
        )

plt.show()

# %%
grafico = sns.relplot(
    data = base,
    x =
    y =
    kind =
    aspect = 
)

for axis in grafico.axes.flat:
    for i, line in enumerate(axis.lines):
        for (x, y) in line.get_xydata():

        axis.annotate(
            f"{y:.0f}",
            xy = (x, y)
            xytext = (0, 0)
            ha = 'center',
            backgroundcolor = 'white',
            textcoords = 'offset points',
            color = line.get_color()
        )

plt.show()

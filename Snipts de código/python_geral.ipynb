# %%
filtro1 = base['coluna'] == 'categoria_1'
filtro2 = base['coluna'] == 'categoria_2'

base['nova_coluna'] = base[filtro1 + filtro2]

# %%
base['coluna'] != 'categoria'

# %%
base['nova_coluna'] = base['coluna1'] + ' ' + base['coluna2']

# %%
base.style

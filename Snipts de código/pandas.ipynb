# %%
import pandas as pd

# %%
pd.read_csv('base.csv', sep = ';')

# %%
minhabase.to_csv('novo_nome_base', sep = '\tab', index = False)

# %%
base.head()

base.head(10)

# %%
base.copy(deep = True)

# %%
base.map(dicionario)

base['nova_coluna'] = base['coluna_de_relacao'].map(dicionario)

# %%
base.reset_index()

# %%
base['coluna'].value_counts()

# %%
base['coluna'].count()

# %%
base['coluna'].unique()

# %%
base['coluna'].nunique()

# %%
base['coluna'].isna()

# %%
base.rename(columns = {'nome_antigo': 'nome_novo'})

# %%
base.melt(
    id_vars = ['colunas_que_quero_manter']
    value_vars = ['colunas_que_quero_derreter']
)

# %%
base.pivot_table(
    index = 
    columns = 
    values = 
    aggfunc = 
    fill_value = 
    margins = True
)

# %%
base.groupby(['colunas'])

# %%
base.query()

# %%
base.transform()

# %%
base.style.format(formatter = {'coluna': '{:.0%}'})

# %%
base.loc[]

# %%
base.iloc[]

# %%
base.drop_duplicates()

# %%
pd.date_range(base.index.min(), base.index.max())

# %%
base.index = pd.DatetimeIndex(base.index)

# %%
base.reindex(datas, fill_value = 0)

# %%
base.apply()

# %%
base.agg(
    base = pd.NameAgg
)
